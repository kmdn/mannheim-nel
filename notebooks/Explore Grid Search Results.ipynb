# %%
import pandas as pd

# %%
df1 = pd.read_csv('/work/rogupta/mannheim-nel-data/models/2018_12_28/conll_new_feature_grid/hyper_df.csv')
df2 = pd.read_csv('/work/rogupta/mannheim-nel-data/models/2018_12_28/conll_new_feature_grid_2/hyper_df.csv')
df = pd.concat([df1, df2])

# %%
df = df.drop(labels=["Unnamed: 0"], axis=1)

# %%
df.sort_values('conll', ascending=False)
# Out:
#         conll   dp  hidden_size     lr  num_candidates other_optim  \
# 49  88.415780  0.1         2000  0.001             256     rmsprop
# 29  88.353162  0.3         2000  0.010             256     rmsprop
# 19  88.332290  0.2         3000  0.001             256     rmsprop
# 42  88.269672  0.2         3000  0.001             256        adam
# 28  88.081820  0.3         2000  0.001             256     rmsprop
# 5   88.081820  0.2         3000  0.050             128     rmsprop
# 46  88.019203  0.3         2000  0.010             256     rmsprop
# 41  87.935713  0.1         2000  0.010             128     rmsprop
# 21  87.914840  0.1         3000  0.001             256        adam
# 38  87.893968  0.2         1000  0.001             128        adam
# 25  87.789606  0.3         2000  0.001             128     rmsprop
# 37  87.768733  0.1         1000  0.001             256        adam
# 30  87.747861  0.3         3000  0.001             128     rmsprop
# ...

# %%
df.corr()
# Out:
#                         conll        dp  hidden_size        lr  \
# conll                1.000000 -0.577115     0.013266 -0.343474
# dp                  -0.577115  1.000000    -0.026314 -0.039372
# hidden_size          0.013266 -0.026314     1.000000  0.008855
# lr                  -0.343474 -0.039372     0.008855  1.000000
# num_candidates       0.016205 -0.017911     0.078702 -0.071985
# prop_gen_candidates -0.135861  0.036719     0.043091  0.081363
# wd                  -0.126053  0.077242    -0.002235 -0.043868
#
#                      num_candidates  prop_gen_candidates        wd
# conll                      0.016205            -0.135861 -0.126053
# dp                        -0.017911             0.036719  0.077242
# hidden_size                0.078702             0.043091 -0.002235
# lr                        -0.071985             0.081363 -0.043868
# num_candidates             1.000000             0.050932 -0.021296
# ...
